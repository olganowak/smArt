# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image, ExifTags
from matplotlib import image
from matplotlib import pyplot
import csv
import os

# %%
df = pd.read_csv("./data_info.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/d7/ns81cvcs75q1gk1wshhtnt4m0000gn/T/ipykernel_92101/368995813.py in <module>
# ----> 1 df = pd.read_csv("./data_info.csv")
#       2 df
#
# ~/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: './data_info.csv'

# %%
list_of_arrays = []

# %%
import glob, os
import pandas as pd
from PIL import Image
data = ['Realism', 'Impressionism']

# %%
for genre in data:
    for infile in glob.glob("./wikiart/" + genre):
        print(infile)

# %%
data = ['Realism', 'Impressionism']

for index, genre in enumerate(data):
    print(f"the genre is {genre}")
    g = os.listdir("../smArt/data/wikiart/wikiart/" + genre)
    for i, painting in enumerate(g):
        string = g[i][:-4]
        string = string.replace("-"," ")
        string = string.split("_")
        string.insert(0, genre)
        paintings_list.append(string)
        with Image.open(infile) as im:
            img_resized = im.resize(size)
            image_array = np.array(img_resized)
            paintings_list.append(image_array)
        
        if i % 100 == 0:
            print(i+1)

# %%
paintings_list = []
size = 128, 128
data = ['Realism', 'Impressionism']

for index, genre in enumerate(data):
    print(f"the genre is {genre}")
    g = os.listdir("../smArt/data/wikiart/wikiart/" + genre)

    
    
    
    for infile in glob.glob("./wikiart/Ukiyo_e/*.jpg"):
    file, ext = os.path.splitext(infile)
              
    for i, painting in enumerate(g):
        string = g[i][:-4]
        string = string.replace("-"," ")
        string = string.split("_")
        string.insert(0, genre)
        paintings_list.append(string)
        with Image.open(infile) as im:
            img_resized = im.resize(size)
            image_array = np.array(img_resized)
            paintings_list.append(image_array)
        
        if i % 100 == 0:
            print(i+1)
# Out:
# the genre is Realism
# 1
# 101
# 201
# 301
# 401
# 501
# 601
# 701
# 801
# 901
# 1001
# 1101
# 1201
# 1301
# 1401
# 1501
# 1601
# 1701
# 1801
# 1901
# 2001
# 2101
# 2201
# 2301
# 2401
# 2501
# 2601
# 2701
# 2801
# 2901
# 3001
# 3101
# 3201
# 3301
# 3401
# 3501
# 3601
# 3701
# 3801
# 3901
# 4001
# 4101
# 4201
# 4301
# 4401
# 4501
# 4601
# 4701
# 4801
# 4901
# 5001
# 5101
# 5201
# 5301
# 5401
# 5501
# 5601
# 5701
# 5801
# 5901
# 6001
# 6101
# 6201
# 6301
# 6401
# 6501
# 6601
# 6701
# 6801
# 6901
# 7001
# 7101
# 7201
# 7301
# 7401
# 7501
# 7601
# 7701
# 7801
# 7901
# 8001
# 8101
# 8201
# 8301
# 8401
# 8501
# 8601
# 8701
# 8801
# 8901
# 9001
# 9101
# 9201
# 9301
# 9401
# 9501
# 9601
# 9701
# 9801
# 9901
# 10001
# 10101
# 10201
# 10301
# 10401
# 10501
# 10601
# 10701
# the genre is Impressionism
# 1
# 101
# 201
# 301
# 401
# 501
# 601
# 701
# 801
# 901
# 1001
# 1101
# 1201
# 1301
# 1401
# 1501
# 1601
# 1701
# 1801
# 1901
# 2001
# 2101
# 2201
# 2301
# 2401
# 2501
# 2601
# 2701
# 2801
# 2901
# 3001
# 3101
# 3201
# 3301
# 3401
# 3501
# 3601
# 3701
# 3801
# 3901
# 4001
# 4101
# 4201
# 4301
# 4401
# 4501
# 4601
# 4701
# 4801
# 4901
# 5001
# 5101
# 5201
# 5301
# 5401
# 5501
# 5601
# 5701
# 5801
# 5901
# 6001
# 6101
# 6201
# 6301
# 6401
# 6501
# 6601
# 6701
# 6801
# 6901
# 7001
# 7101
# 7201
# 7301
# 7401
# 7501
# 7601
# 7701
# 7801
# 7901
# 8001
# 8101
# 8201
# 8301
# 8401
# 8501
# 8601
# 8701
# 8801
# 8901
# 9001
# 9101
# 9201
# 9301
# 9401
# 9501
# 9601
# 9701
# 9801
# 9901
# 10001
# 10101
# 10201
# 10301
# 10401
# 10501
# 10601
# 10701
# 10801
# 10901
# 11001
# 11101
# 11201
# 11301
# 11401
# 11501
# 11601
# 11701
# 11801
# 11901
# 12001
# 12101
# 12201
# 12301
# 12401
# 12501
# 12601
# 12701
# 12801
# 12901
# 13001

# %%
pd.DataFrame(paintings_list)
# Out:
#                    0                         1  \
# 0            Realism  henry herbert la thangue
# 1            Realism             ivan shishkin
# 2            Realism         theodore rousseau
# 3            Realism             isaac levitan
# 4            Realism                ilya repin
# ...              ...                       ...
# 23788  Impressionism               kimon loghi
# 23789  Impressionism           willard metcalf
# 23790  Impressionism       maurice prendergast
# 23791  Impressionism    victor borisov musatov
# 23792  Impressionism            berthe morisot
#
#                                                      2         3       4
# 0                             a mission to seamen 1891      None    None
# 1                                              ravines      None    None
# 2                                                  not  detected  198951
# 3                                                fires      None    None
# 4      portrait of the art critic vladimir stasov 1889      None    None
# ...                                                ...       ...     ...
# 23788                                         the tree      None    None
# 23789                                          october      None    None
# 23790                 handkerchief point coastal scene      None    None
# 23791             in the light of the setting sun 1904      None    None
# 23792              little girl with a blue jersey 1886      None    None
#
# [23793 rows x 5 columns]

# %%
from PIL import Image
import glob, os

size = 128, 128

for infile in glob.glob("./wikiart/Ukiyo_e/*.jpg"):
    file, ext = os.path.splitext(infile)
    with Image.open(infile) as im:
        img_resized = im.resize(size)
        image_array = np.array(img_resized)
        print(image_array.shape)
        list_of_arrays.append(image_array)

# %%
plt.imshow(list_of_arrays[1020])

# %%
np.asarray(list_of_arrays)[0].shape

# %%
df_array = pd.DataFrame({'col':list_of_arrays})

# %%
df_array

# %%
plt.imshow(df_array["col"][0])

# %%
df_array.to_csv("weebart.csv")

# %%
# Import pandas library
import pandas as pd
 
# initialize list of lists
data = [['tom', 10], ['nick', 15], ['juli', 14]]
 
# Create the pandas DataFrame
df = pd.DataFrame(data, columns=['Name', 'Age'])
 
# print dataframe.
df
# Out:
#    Name  Age
# 0   tom   10
# 1  nick   15
# 2  juli   14

# %%
df.drop(index=0)
# Out:
#    Name  Age
# 1  nick   15
# 2  juli   14
